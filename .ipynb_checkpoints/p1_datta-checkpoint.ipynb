# %%
# supress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# imports
import pandas as pd
import numpy as np
from pandas.api.types import is_numeric_dtype
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
import category_encoders as ce
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV

# %%
# read data
trainData = pd.read_csv('./train.csv')
testData = pd.read_csv('./test.csv')

# Remove first NaN and id columns, they seem to serve no purpose
trainData = trainData.iloc[:, 2:]
testData = testData.iloc[:, 2:]

trainData.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 23 columns]

# %%
# merge train and test data
mergedData = trainData.append(testData)

# %%
# initial data exploration
total_records = mergedData.shape[0]
test_records = testData.shape[0]
training_records = trainData.shape[0]
print(f'Number of records in train data: {training_records}\nNumber of records in test data: {test_records}\n')

print('Percentages of the total records present in testing and training datasets:')
print(f'Training dataset: {(training_records/total_records)*100:.2f}%')
print(f'Test dataset: {(test_records/total_records)*100:.2f}%\n')

missing_values = mergedData.isnull().sum()
for i in range(0, len(trainData.columns)):
    if(missing_values[i] > 0):
        print(f'"{trainData.columns[i]}" column contains {missing_values[i]} missing values.')

missing_vals = mergedData.isnull().sum()[21]
counter = 0
null_val = mergedData['Arrival Delay in Minutes'].isnull()
for i in range(0, len(null_val)):
    if null_val.iloc[i]:
        if mergedData.iloc[i, -1] == 'satisfied':
            counter += 1
print(f'Satisfied customers with missing data: {(counter/missing_vals)*100:.3f}%\n')
        
neu_dis = mergedData['satisfaction'].value_counts()[0]
sas = mergedData['satisfaction'].value_counts()[1]
total = neu_dis + sas
print(f'Neutral or dissatisfied passengers: {(neu_dis/(total)) * 100:.3f}%\nSatisfied Passengers: {(sas/(total)) * 100:.3f}%')
print()
# Out:
# Number of records in train data: 103904
# Number of records in test data: 25976
#
# Percentages of the total records present in testing and training datasets:
# Training dataset: 80.00%
# Test dataset: 20.00%
#
# "Arrival Delay in Minutes" column contains 393 missing values.
# Satisfied customers with missing data: 42.239%
#
# Neutral or dissatisfied passengers: 56.554%
# Satisfied Passengers: 43.446%

# %%
# data exploration with statistical analysis
removed_zeroes = mergedData
indexNames = removed_zeroes[ (removed_zeroes['Inflight wifi service'] == 0) | (removed_zeroes['Departure/Arrival time convenient'] == 0)
                          | (removed_zeroes['Ease of Online booking'] == 0) | (removed_zeroes['Gate location'] == 0) 
                          | (removed_zeroes['Food and drink'] == 0) | (removed_zeroes['Online boarding'] == 0)
                          | (removed_zeroes['Seat comfort'] == 0) | (removed_zeroes['Inflight entertainment'] == 0)
                          | (removed_zeroes['On-board service'] == 0) | (removed_zeroes['Leg room service'] == 0)
                          | (removed_zeroes['Baggage handling'] == 0) | (removed_zeroes['Checkin service'] == 0)
                          | (removed_zeroes['Inflight service'] == 0) | (removed_zeroes['Cleanliness'] == 0)].index
removed_zeroes.drop(indexNames, inplace=True)

mean = []
std = []
cols = []

stats = []
for col in removed_zeroes.columns:
    if(col != "Age" and col != "Flight Distance" and col != "Departure Delay in Minutes" and col != "Arrival Delay in Minutes"):
        if is_numeric_dtype(removed_zeroes[col]):
            temp = []

            temp.append(col)
            temp.append(removed_zeroes[col].mean())
            temp.append(removed_zeroes[col].std())

            stats.append(temp)

stats_df = pd.DataFrame(data=stats)
stats_df.columns = ['', 'Mean', 'Std. Dev.']
stats_df
# Out:
#                                            Mean  Std. Dev.
# 0               Inflight wifi service  2.818924   1.253488
# 1   Departure/Arrival time convenient  3.206529   1.386967
# 2              Ease of Online booking  2.879038   1.298530
# 3                       Gate location  2.987187   1.282230
# 4                      Food and drink  3.212538   1.324593
# 5                     Online boarding  3.329783   1.263577
# 6                        Seat comfort  3.456304   1.312268
# 7              Inflight entertainment  3.379790   1.327307
# 8                    On-board service  3.386559   1.285585
# 9                    Leg room service  3.381562   1.295240
# 10                   Baggage handling  3.638669   1.167754
# 11                    Checkin service  3.293592   1.265982
# 12                   Inflight service  3.647271   1.165077
# 13                        Cleanliness  3.293557   1.310130

# %%
# specific data exploration 

# by age
avg_age = np.mean(np.array(mergedData['Age'].to_list()).astype(np.float))
print(f'Mean age of passengers: {avg_age:.3f}')

print()
sat_age = []
dissat_age = []
age_array = np.array(mergedData['Age'].to_list()).astype(np.float)
for i in range(0, len(age_array)):
    if mergedData.iloc[i, -1] == 'satisfied':
        sat_age.append(age_array[i])
    else:
        dissat_age.append(age_array[i])

print(f'Mean age of satisfied passengers: {np.mean(sat_age):.3f}')
print(f'Mean age of dissatisfied passengers: {np.mean(dissat_age):.3f}')
# Out:
# Mean age of passengers: 39.853
#
# Mean age of satisfied passengers: 42.512
# Mean age of dissatisfied passengers: 37.872

# %%
# analyzing satisfaction within different classes
business = mergedData['Class'].value_counts()[0]
eco = mergedData['Class'].value_counts()[1]
ecoPlus = mergedData['Class'].value_counts()[2]
total = business + eco + ecoPlus

print(f'Percent of Business Class passengers: {(business/total)*100:.3f}%')
print(f'Percent of Eco Class passengers: {(eco/total)*100:.3f}%')
print(f'Percent of Eco Plus Class passengers: {(ecoPlus/total)*100:.3f}%')
print()

# Business class satisfaction
business_total = 0
eco_total = 0
ecoPlus_total = 0

for value in mergedData.itertuples():
    if value[5] == 'Business':
        if value[-1] == 'satisfied':
            business_total += 1
    elif value[5] == 'Eco':
        if value[-1] == 'satisfied':
            eco_total += 1
    elif value[5] == 'Eco Plus':
        if value[-1] == 'satisfied':
            ecoPlus_total += 1
            
print(f'Percent of satisfied Business Class passengers: {(business_total/business)*100:.3f}%')
print(f'Percent of satisfied Eco Class passengers: {(eco_total/eco)*100:.3f}%')
print(f'Percent of satisfied Eco Plus Class passengers: {(ecoPlus_total/ecoPlus)*100:.3f}%')
# Out:
# Percent of Business Class passengers: 48.626%
# Percent of Eco Class passengers: 44.040%
# Percent of Eco Plus Class passengers: 7.333%
#
# Percent of satisfied Business Class passengers: 68.528%
# Percent of satisfied Eco Class passengers: 17.395%
# Percent of satisfied Eco Plus Class passengers: 23.261%

# %%
# Create the training and testing data 
x_train = trainData.drop(['satisfaction'], axis=1)
y_train = trainData['satisfaction']

x_test = testData.drop(['satisfaction'], axis=1)
y_test = testData['satisfaction']

# %%
# Encode ordinal fields
encoder = ce.OrdinalEncoder(cols=['Gender', 'Customer Type', 'Type of Travel', 'Class'])
x_train = encoder.fit_transform(x_train)
x_test = encoder.transform(x_test)

target_encoder = ce.OrdinalEncoder(cols=['satisfaction'])
y_train = target_encoder.fit_transform(y_train)
y_test = target_encoder.transform(y_test)

# %%
# Impute missing values with the mean strategy
imputer = SimpleImputer(missing_values = np.nan, strategy="mean")
x_train['Arrival Delay in Minutes'] = imputer.fit_transform(x_train[['Arrival Delay in Minutes']])
x_test['Arrival Delay in Minutes'] = imputer.transform(x_test[['Arrival Delay in Minutes']])

# %%
# decision tree 
tree_clf = DecisionTreeClassifier().fit(x_train, y_train)

print(f'Cross Validation:\n{cross_val_score(tree_clf, x_train, y_train, cv=5)}')
print()

tree_predictions = tree_clf.predict(x_test)
print(f'Decision Tree model accuracy score on test data:\n{accuracy_score(y_test, tree_predictions):.4f}\n')
print(f'Confusion matrix:\n{confusion_matrix(y_test, tree_predictions)}\n')
print(f'Classification report:\n{classification_report(y_test, tree_predictions)}')
# Out:
# Cross Validation:
# [0.94052259 0.94605649 0.9453828  0.94345797 0.94369586]
#
# Decision Tree model accuracy score on test data:
# 0.9461
#
# Confusion matrix:
# [[13854   719]
#  [  680 10723]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            1       0.95      0.95      0.95     14573
#            2       0.94      0.94      0.94     11403
#
#     accuracy                           0.95     25976
#    macro avg       0.95      0.95      0.95     25976
# weighted avg       0.95      0.95      0.95     25976

# %%
# mlp classifier 
mlp_clf = MLPClassifier(hidden_layer_sizes=(10, 10, 10)).fit(x_train, y_train)

print(f'\nCross Validation Scores:\n{cross_val_score(mlp_clf, x_train, y_train, cv=5)}\n')

predictions = mlp_clf.predict(x_test)
print(f'MLP Classifier accuracy score on test data:\n{accuracy_score(y_test, predictions):.4f}\n')
print(f'Confusion matrix:\n{confusion_matrix(y_test, predictions)}\n')
print(f'Classification report:\n{classification_report(y_test, predictions)}')
# Out:
# Cross Validation Scores:
# [0.91934941 0.92738559 0.92594197 0.92425774 0.92786333]
#
# MLP Classifier accuracy score on test data:
# 0.9279
#
# Confusion matrix:
# [[13484  1089]
#  [  784 10619]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            1       0.95      0.93      0.94     14573
#            2       0.91      0.93      0.92     11403
#
#     accuracy                           0.93     25976
#    macro avg       0.93      0.93      0.93     25976
# weighted avg       0.93      0.93      0.93     25976

# %%
print(f'The decision tree is {(accuracy_score(y_test, tree_predictions) - accuracy_score(y_test, predictions)) * 100:.4f}% more accurate than MLP classifier')
# Out:
# The decision tree is 1.8248% more accurate than MLP classifier

# %%
# Random Forest Model
forest_clf = RandomForestClassifier().fit(x_train, y_train)

print(f'\nCross Validation Scores:\n{cross_val_score(forest_clf, x_train, y_train, cv=5)}\n')

predictions_randForest = forest_clf.predict(x_test)
print(f'Random Forest model accuracy score on test data:\n{accuracy_score(y_test, predictions_randForest):.4f}\n')
print(f'Confusion matrix:\n{confusion_matrix(y_test, predictions_randForest)}\n')
print(f'Classification report:\n{classification_report(y_test, predictions_randForest)}')
# Out:
# Cross Validation Scores:
# [0.95649872 0.95606564 0.95399644 0.95568067 0.95818094]
#
# Random Forest model accuracy score on test data:
# 0.9565
#
# Confusion matrix:
# [[14228   345]
#  [  786 10617]]
#
# Classification report:
#               precision    recall  f1-score   support
#
#            1       0.95      0.98      0.96     14573
#            2       0.97      0.93      0.95     11403
#
#     accuracy                           0.96     25976
#    macro avg       0.96      0.95      0.96     25976
# weighted avg       0.96      0.96      0.96     25976

# %%
print(f'The random forest model is {(accuracy_score(y_test, predictions_randForest) - accuracy_score(y_test, tree_predictions)) * 100:.4f}% more accurate than Decision Tree')
# Out:
# The random forest model is 1.0317% more accurate than Decision Tree

# %%
# Grid search for Decision Tree 
parameters = {'criterion' : ['gini', 'entropy'],
              'splitter': ['best', 'random'],
              'max_depth': [None, 2, 4, 16, 32],
              'min_samples_split': [2, 4, 8, 16],
              'min_samples_leaf': [1, 2, 4, 8],
              'max_features' : [None, 'auto', 'sqrt', 'log2']
             }

gridClf = GridSearchCV(DecisionTreeClassifier(), parameters, cv=3)
gridClf.fit(x_train, y_train)

print("\nBest parameters for Decision Tree:", gridClf.best_params_, "\n")

means = gridClf.cv_results_['mean_test_score']
stds = gridClf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, gridClf.cv_results_['params']):
    print("Mean: %0.3f, Std Dev: (+/-%0.03f), Parameters: %r"% (mean, std * 2, params))
    print()
# Out:
# Best parameters for Decision Tree: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.943, Std Dev: (+/-0.001), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.943, Std Dev: (+/-0.001), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.944, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.945, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.945, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.948, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.948, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.949, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.945, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.946, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.945, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.947, Std Dev: (+/-0.001), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.946, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.947, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.949, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.949, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.947, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.949, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.947, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.948, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.947, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.947, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.949, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.949, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.948, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.949, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.948, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.950, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.948, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.948, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.948, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.949, Std Dev: (+/-0.001), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.923, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.919, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.928, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.918, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.938, Std Dev: (+/-0.001), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.007), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.007), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.927, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.918, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.013), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.011), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.013), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.927, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.928, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.005), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.014), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.919, Std Dev: (+/-0.012), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.015), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.920, Std Dev: (+/-0.017), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.012), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.927, Std Dev: (+/-0.011), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.920, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.930, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.918, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.928, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.929, Std Dev: (+/-0.005), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.929, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.930, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.017), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.012), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.014), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.014), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.927, Std Dev: (+/-0.009), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.001), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.009), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.928, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.920, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.007), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.916, Std Dev: (+/-0.020), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.930, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.014), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.007), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.015), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.920, Std Dev: (+/-0.012), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.926, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.916, Std Dev: (+/-0.001), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.931, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.011), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.007), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.009), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.018), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.007), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.009), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.930, Std Dev: (+/-0.012), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.919, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.007), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.009), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.009), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.927, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.917, Std Dev: (+/-0.015), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.931, Std Dev: (+/-0.005), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.007), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.937, Std Dev: (+/-0.014), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.801, Std Dev: (+/-0.067), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.809, Std Dev: (+/-0.071), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.780, Std Dev: (+/-0.071), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.818, Std Dev: (+/-0.054), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.781, Std Dev: (+/-0.063), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.837, Std Dev: (+/-0.052), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.779, Std Dev: (+/-0.070), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.793, Std Dev: (+/-0.092), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.810, Std Dev: (+/-0.074), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.810, Std Dev: (+/-0.046), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.803, Std Dev: (+/-0.090), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.803, Std Dev: (+/-0.094), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.813, Std Dev: (+/-0.055), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.813, Std Dev: (+/-0.061), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.823, Std Dev: (+/-0.032), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.807, Std Dev: (+/-0.061), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.777, Std Dev: (+/-0.101), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.706, Std Dev: (+/-0.035), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.782, Std Dev: (+/-0.128), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.730, Std Dev: (+/-0.075), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.779, Std Dev: (+/-0.094), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.705, Std Dev: (+/-0.032), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.778, Std Dev: (+/-0.043), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.691, Std Dev: (+/-0.177), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.784, Std Dev: (+/-0.038), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.721, Std Dev: (+/-0.115), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.744, Std Dev: (+/-0.074), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.672, Std Dev: (+/-0.097), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.762, Std Dev: (+/-0.114), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.736, Std Dev: (+/-0.104), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.799, Std Dev: (+/-0.067), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.747, Std Dev: (+/-0.102), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.751, Std Dev: (+/-0.040), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.694, Std Dev: (+/-0.158), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.777, Std Dev: (+/-0.070), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.699, Std Dev: (+/-0.167), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.803, Std Dev: (+/-0.057), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.742, Std Dev: (+/-0.100), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.772, Std Dev: (+/-0.025), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.761, Std Dev: (+/-0.015), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.749, Std Dev: (+/-0.106), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.773, Std Dev: (+/-0.043), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.773, Std Dev: (+/-0.094), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.744, Std Dev: (+/-0.028), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.782, Std Dev: (+/-0.042), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.715, Std Dev: (+/-0.083), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.795, Std Dev: (+/-0.097), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.733, Std Dev: (+/-0.089), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.779, Std Dev: (+/-0.070), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.698, Std Dev: (+/-0.123), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.792, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.733, Std Dev: (+/-0.164), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.770, Std Dev: (+/-0.033), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.763, Std Dev: (+/-0.047), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.795, Std Dev: (+/-0.011), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.668, Std Dev: (+/-0.049), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.736, Std Dev: (+/-0.018), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.731, Std Dev: (+/-0.161), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.795, Std Dev: (+/-0.051), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.782, Std Dev: (+/-0.037), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.759, Std Dev: (+/-0.046), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.687, Std Dev: (+/-0.093), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.785, Std Dev: (+/-0.105), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.693, Std Dev: (+/-0.131), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.785, Std Dev: (+/-0.117), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.665, Std Dev: (+/-0.068), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.779, Std Dev: (+/-0.094), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.768, Std Dev: (+/-0.046), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.740, Std Dev: (+/-0.081), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.776, Std Dev: (+/-0.038), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.782, Std Dev: (+/-0.043), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.713, Std Dev: (+/-0.038), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.786, Std Dev: (+/-0.028), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.717, Std Dev: (+/-0.102), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.808, Std Dev: (+/-0.025), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.706, Std Dev: (+/-0.082), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.766, Std Dev: (+/-0.081), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.729, Std Dev: (+/-0.046), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.768, Std Dev: (+/-0.080), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.714, Std Dev: (+/-0.093), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.738, Std Dev: (+/-0.101), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.706, Std Dev: (+/-0.116), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.771, Std Dev: (+/-0.052), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.724, Std Dev: (+/-0.127), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.763, Std Dev: (+/-0.085), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.718, Std Dev: (+/-0.068), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.762, Std Dev: (+/-0.066), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.716, Std Dev: (+/-0.087), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.790, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.753, Std Dev: (+/-0.126), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.784, Std Dev: (+/-0.102), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.699, Std Dev: (+/-0.197), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.773, Std Dev: (+/-0.038), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.699, Std Dev: (+/-0.136), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.778, Std Dev: (+/-0.032), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.740, Std Dev: (+/-0.139), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.776, Std Dev: (+/-0.023), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.693, Std Dev: (+/-0.093), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.762, Std Dev: (+/-0.080), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.725, Std Dev: (+/-0.113), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.830, Std Dev: (+/-0.042), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.652, Std Dev: (+/-0.023), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.804, Std Dev: (+/-0.034), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.652, Std Dev: (+/-0.033), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.744, Std Dev: (+/-0.047), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.671, Std Dev: (+/-0.016), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.770, Std Dev: (+/-0.082), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.667, Std Dev: (+/-0.054), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.756, Std Dev: (+/-0.069), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.716, Std Dev: (+/-0.064), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.786, Std Dev: (+/-0.028), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.650, Std Dev: (+/-0.108), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.881, Std Dev: (+/-0.020), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.858, Std Dev: (+/-0.021), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.893, Std Dev: (+/-0.022), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.872, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.883, Std Dev: (+/-0.021), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.868, Std Dev: (+/-0.009), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# ...
#
# Mean: 0.930, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.931, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.009), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.928, Std Dev: (+/-0.015), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.012), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.927, Std Dev: (+/-0.006), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.009), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.920, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.938, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.001), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.919, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.916, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.928, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.920, Std Dev: (+/-0.012), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.912, Std Dev: (+/-0.013), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.930, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.920, Std Dev: (+/-0.006), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.930, Std Dev: (+/-0.006), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.013), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.928, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.929, Std Dev: (+/-0.015), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.930, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
# Mean: 0.931, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.001), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.006), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.006), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.009), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.937, Std Dev: (+/-0.018), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.019), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.931, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.917, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.930, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.016), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.919, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.930, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.019), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.938, Std Dev: (+/-0.006), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.001), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.920, Std Dev: (+/-0.021), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.920, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 16, 'splitter': 'random'}
#
# Mean: 0.931, Std Dev: (+/-0.012), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.016), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.928, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.009), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.915, Std Dev: (+/-0.015), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: 0.939, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.009), Parameters: {'criterion': 'entropy', 'max_depth': 32, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 16, 'splitter': 'random'}

# %%
# Grid search for Random Forest model
parameters = {'criterion' : ['gini', 'entropy'],
              'max_depth': [None, 10, 20, 50, 100],
              'max_features': ["auto", "sqrt", "log2"]
             }

gridClf = GridSearchCV(RandomForestClassifier(), parameters, cv=3)
gridClf.fit(x_train, y_train)

print("\nBest parameters for Random Forest:", gridClf.best_params_, "\n")

means = gridClf.cv_results_['mean_test_score']
stds = gridClf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, gridClf.cv_results_['params']):
    print("Mean: %0.3f, Std Dev: (+/-%0.03f), Parameters: %r"% (mean, std * 2, params))
    print()
# Out:
# Best parameters for Random Forest: {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'sqrt'}
#
# Mean: 0.954, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto'}
#
# Mean: 0.955, Std Dev: (+/-0.001), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt'}
#
# Mean: 0.956, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'log2'}
#
# Mean: 0.942, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto'}
#
# Mean: 0.944, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt'}
#
# Mean: 0.943, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2'}
#
# Mean: 0.955, Std Dev: (+/-0.001), Parameters: {'criterion': 'gini', 'max_depth': 20, 'max_features': 'auto'}
#
# Mean: 0.955, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt'}
#
# Mean: 0.955, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2'}
#
# Mean: 0.956, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 50, 'max_features': 'auto'}
#
# Mean: 0.956, Std Dev: (+/-0.001), Parameters: {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt'}
#
# Mean: 0.954, Std Dev: (+/-0.005), Parameters: {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2'}
#
# Mean: 0.956, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 100, 'max_features': 'auto'}
#
# Mean: 0.955, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 100, 'max_features': 'sqrt'}
#
# Mean: 0.955, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2'}
#
# Mean: 0.956, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto'}
#
# Mean: 0.955, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt'}
#
# Mean: 0.955, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2'}
#
# Mean: 0.939, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto'}
#
# Mean: 0.942, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt'}
#
# Mean: 0.942, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2'}
#
# Mean: 0.954, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'auto'}
#
# Mean: 0.956, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt'}
#
# Mean: 0.955, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2'}
#
# Mean: 0.956, Std Dev: (+/-0.001), Parameters: {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'auto'}
#
# Mean: 0.956, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt'}
#
# Mean: 0.954, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2'}
#
# Mean: 0.956, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto'}
#
# Mean: 0.956, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'sqrt'}
#
# Mean: 0.955, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2'}

# %%
# Grid search for Multilayer Perceptron model
parameters = {'solver': ['adam', 'lbfgs', 'sgd'], 
              'activation': ['identity', 'logistic', 'tanh', 'relu'],
              'hidden_layer_sizes': [(10,10,10), (10, 5), (100, 10, 50)],
              'alpha': [.0001, .005], 
              'learning_rate': ['constant', 'adaptive', 'invscaling']}

gridClf = GridSearchCV(MLPClassifier(), parameters, cv=3).fit(x_train, y_train)

print("\nBest parameters for MLP:",gridClf.best_params_,"\n")

means = gridClf.cv_results_['mean_test_score']
stds = gridClf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, gridClf.cv_results_['params']):
    print("Mean: %0.3f, Std Dev: (+/-%0.03f), Parameters: %r"% (mean, std * 2, params))
    print()
# Out:
# Best parameters for MLP: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.848, Std Dev: (+/-0.028), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.566, Std Dev: (+/-0.001), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.834, Std Dev: (+/-0.088), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.541, Std Dev: (+/-0.070), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.859, Std Dev: (+/-0.029), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.536, Std Dev: (+/-0.080), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.855, Std Dev: (+/-0.026), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.576, Std Dev: (+/-0.027), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.834, Std Dev: (+/-0.096), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.563, Std Dev: (+/-0.011), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.830, Std Dev: (+/-0.040), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.533, Std Dev: (+/-0.085), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.867, Std Dev: (+/-0.007), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.446, Std Dev: (+/-0.029), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.865, Std Dev: (+/-0.007), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.566, Std Dev: (+/-0.001), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.865, Std Dev: (+/-0.012), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.519, Std Dev: (+/-0.139), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.856, Std Dev: (+/-0.038), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.586, Std Dev: (+/-0.054), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.825, Std Dev: (+/-0.072), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.560, Std Dev: (+/-0.013), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.868, Std Dev: (+/-0.007), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.576, Std Dev: (+/-0.026), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.864, Std Dev: (+/-0.012), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.578, Std Dev: (+/-0.033), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.842, Std Dev: (+/-0.031), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.545, Std Dev: (+/-0.038), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.855, Std Dev: (+/-0.049), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.517, Std Dev: (+/-0.101), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.854, Std Dev: (+/-0.046), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.547, Std Dev: (+/-0.054), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.865, Std Dev: (+/-0.015), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.523, Std Dev: (+/-0.103), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.866, Std Dev: (+/-0.004), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'identity', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.925, Std Dev: (+/-0.025), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.813, Std Dev: (+/-0.036), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.924, Std Dev: (+/-0.004), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.797, Std Dev: (+/-0.083), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.919, Std Dev: (+/-0.019), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.663, Std Dev: (+/-0.155), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.924, Std Dev: (+/-0.009), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.738, Std Dev: (+/-0.133), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.914, Std Dev: (+/-0.021), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.786, Std Dev: (+/-0.058), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.931, Std Dev: (+/-0.008), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.744, Std Dev: (+/-0.135), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.933, Std Dev: (+/-0.006), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.642, Std Dev: (+/-0.030), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.923, Std Dev: (+/-0.025), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.700, Std Dev: (+/-0.076), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.613, Std Dev: (+/-0.066), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.929, Std Dev: (+/-0.009), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.654, Std Dev: (+/-0.031), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.918, Std Dev: (+/-0.021), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.695, Std Dev: (+/-0.205), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.916, Std Dev: (+/-0.015), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.710, Std Dev: (+/-0.167), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.914, Std Dev: (+/-0.033), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.649, Std Dev: (+/-0.232), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.925, Std Dev: (+/-0.007), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.813, Std Dev: (+/-0.025), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.922, Std Dev: (+/-0.008), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.748, Std Dev: (+/-0.053), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.917, Std Dev: (+/-0.018), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.743, Std Dev: (+/-0.140), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.922, Std Dev: (+/-0.016), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.709, Std Dev: (+/-0.137), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.568, Std Dev: (+/-0.005), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.929, Std Dev: (+/-0.011), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.674, Std Dev: (+/-0.121), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.924, Std Dev: (+/-0.017), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.693, Std Dev: (+/-0.067), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.906, Std Dev: (+/-0.020), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.779, Std Dev: (+/-0.068), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.566, Std Dev: (+/-0.001), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.880, Std Dev: (+/-0.046), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.778, Std Dev: (+/-0.055), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.912, Std Dev: (+/-0.015), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.753, Std Dev: (+/-0.173), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.566, Std Dev: (+/-0.001), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.877, Std Dev: (+/-0.034), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.771, Std Dev: (+/-0.105), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.901, Std Dev: (+/-0.033), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.739, Std Dev: (+/-0.134), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.566, Std Dev: (+/-0.000), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.912, Std Dev: (+/-0.007), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.734, Std Dev: (+/-0.237), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.564, Std Dev: (+/-0.003), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.909, Std Dev: (+/-0.015), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.711, Std Dev: (+/-0.086), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.568, Std Dev: (+/-0.004), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.906, Std Dev: (+/-0.009), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.695, Std Dev: (+/-0.081), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.626, Std Dev: (+/-0.083), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.916, Std Dev: (+/-0.014), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.729, Std Dev: (+/-0.042), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.566, Std Dev: (+/-0.000), Parameters: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.890, Std Dev: (+/-0.040), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.749, Std Dev: (+/-0.137), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.901, Std Dev: (+/-0.041), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.669, Std Dev: (+/-0.153), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.568, Std Dev: (+/-0.005), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.905, Std Dev: (+/-0.038), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.772, Std Dev: (+/-0.159), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.566, Std Dev: (+/-0.002), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.898, Std Dev: (+/-0.028), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.678, Std Dev: (+/-0.047), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.566, Std Dev: (+/-0.001), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.915, Std Dev: (+/-0.016), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.760, Std Dev: (+/-0.101), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.611, Std Dev: (+/-0.127), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.905, Std Dev: (+/-0.018), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.763, Std Dev: (+/-0.102), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.565, Std Dev: (+/-0.001), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.922, Std Dev: (+/-0.013), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.706, Std Dev: (+/-0.043), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.002), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.925, Std Dev: (+/-0.003), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.783, Std Dev: (+/-0.055), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.701, Std Dev: (+/-0.083), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.910, Std Dev: (+/-0.012), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.694, Std Dev: (+/-0.007), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.566, Std Dev: (+/-0.000), Parameters: {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.896, Std Dev: (+/-0.070), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.920, Std Dev: (+/-0.015), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.649, Std Dev: (+/-0.234), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.920, Std Dev: (+/-0.017), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.566, Std Dev: (+/-0.001), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.886, Std Dev: (+/-0.033), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.625, Std Dev: (+/-0.166), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.900, Std Dev: (+/-0.037), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.525, Std Dev: (+/-0.115), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.768, Std Dev: (+/-0.285), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.509, Std Dev: (+/-0.213), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.918, Std Dev: (+/-0.052), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.522, Std Dev: (+/-0.126), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.924, Std Dev: (+/-0.011), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.546, Std Dev: (+/-0.059), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.925, Std Dev: (+/-0.011), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.922, Std Dev: (+/-0.013), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.567, Std Dev: (+/-0.001), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.001), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.918, Std Dev: (+/-0.008), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.565, Std Dev: (+/-0.002), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.911, Std Dev: (+/-0.027), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.524, Std Dev: (+/-0.119), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.566, Std Dev: (+/-0.001), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.904, Std Dev: (+/-0.058), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.532, Std Dev: (+/-0.141), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.680, Std Dev: (+/-0.320), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.478, Std Dev: (+/-0.125), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.899, Std Dev: (+/-0.056), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.565, Std Dev: (+/-0.002), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.478, Std Dev: (+/-0.126), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'invscaling', 'solver': 'sgd'}
#
# Mean: 0.908, Std Dev: (+/-0.006), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'adam'}
#
# Mean: 0.566, Std Dev: (+/-0.002), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
#
# Mean: 0.913, Std Dev: (+/-0.023), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
#
# Mean: 0.544, Std Dev: (+/-0.065), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
#
# Mean: 0.916, Std Dev: (+/-0.021), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'adam'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'invscaling', 'solver': 'sgd'}

# %%
# Making the models with the best parameters from grid search 
# decision tree 
tuned_tree_clf = DecisionTreeClassifier(criterion='entropy', max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=16, splitter='random').fit(x_train, y_train)

tuned_tree_predictions = tuned_tree_clf.predict(x_test)
print(f'Tuned Decision Tree accuracy score on test data:\n{accuracy_score(y_test, tuned_tree_predictions):.4f}\n')
# Out:
# Tuned Decision Tree accuracy score on test data:
# 0.9539

# %%
# Random Forest Model
tuned_forest_clf = RandomForestClassifier(criterion='entropy', max_depth=100, max_features='sqrt').fit(x_train, y_train)

tuned_predictions_randForest = tuned_forest_clf.predict(x_test)
print(f'Tuned Random Forest accuracy score on test data:\n{accuracy_score(y_test, tuned_predictions_randForest):.4f}\n')
# Out:
# Tuned Random Forest accuracy score on test data:
# 0.9585

# %%
# mlp classifier 
tuned_mlp_clf = MLPClassifier(activation='logistic', alpha=0.0001, hidden_layer_sizes=(100,10,50), learning_rate='constant', solver='adam').fit(x_train, y_train)

tuned_predictions = tuned_mlp_clf.predict(x_test)
print(f'Tuned MLP Classifier accuracy score on test data:\n{accuracy_score(y_test, tuned_predictions):.4f}\n')
# Out:
# Tuned MLP Classifier accuracy score on test data:
# 0.9306

# %%
# difference between untuned and tuned accuracy scores
decisionTree = accuracy_score(y_test, tuned_tree_predictions) - accuracy_score(y_test, tree_predictions)
randomForest = accuracy_score(y_test, tuned_predictions_randForest) - accuracy_score(y_test, predictions_randForest)
mlpClassifier = accuracy_score(y_test, tuned_predictions) - accuracy_score(y_test, predictions)

print(f'Tuned Decision Tree accuracy gain: {decisionTree:.4f} or {decisionTree * 100:.4f}%')
print(f'Tuned Random Forest accuracy gain: {randomForest:.4f} or {randomForest * 100:.4f}%')
print(f'Tuned MLP Classifier accuracy gain: {mlpClassifier:.4f} or {mlpClassifier * 100:.4f}%')
# Out:
# Tuned Decision Tree accuracy gain: 0.0077 or 0.7738%
# Tuned Random Forest accuracy gain: 0.0020 or 0.2002%
# Tuned MLP Classifier accuracy gain: 0.0027 or 0.2656%

# %%
# checking for overfitting and underfitting 
print("Checking for overfitting and underfitting\n")
tree_train_predictions = tuned_tree_clf.predict(x_train)
forest_train_predictions = tuned_forest_clf.predict(x_train)
mlp_train_predictions = tuned_mlp_clf.predict(x_train)

print("Decision tree:")
print(f'Training set accuracy score: {accuracy_score(y_train, tree_train_predictions):.4f}')
print(f'Test set accuracy score: {accuracy_score(y_test, tuned_tree_predictions):.4f}')
print(f'Difference: {accuracy_score(y_train, tree_train_predictions) - accuracy_score(y_test, tuned_tree_predictions):.4f}\n')

print("Random Forest:")
print(f'Training accuracy set score: {accuracy_score(y_train, forest_train_predictions):.4f}')
print(f'Test set accuracy score: {accuracy_score(y_test, tuned_predictions_randForest):.4f}')
print(f'Difference: {accuracy_score(y_train, forest_train_predictions) - accuracy_score(y_test, tuned_predictions_randForest):.4f}\n')

print("MLP Classifier:")
print(f'Training accuracy set score: {accuracy_score(y_train, mlp_train_predictions):.4f}')
print(f'Test set accuracy score: {accuracy_score(y_test, tuned_predictions):.4f}')
print(f'Difference: {accuracy_score(y_train, mlp_train_predictions) - accuracy_score(y_test, tuned_predictions):.4f}\n')
# Out:
# Checking for overfitting and underfitting
#
# Decision tree:
# Training set accuracy score: 0.9738
# Test set accuracy score: 0.9539
# Difference: 0.0199
#
# Random Forest:
# Training accuracy set score: 0.9973
# Test set accuracy score: 0.9577
# Difference: 0.0396
#
# MLP Classifier:
# Training accuracy set score: 0.9323
# Test set accuracy score: 0.9306
# Difference: 0.0017
