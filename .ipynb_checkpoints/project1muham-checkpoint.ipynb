# %%
### imports and warning filters ###
import pandas as pd
import matplotlib as mplib
import numpy as np
import sklearn as sk
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import category_encoders as ce
import warnings
from sklearn.impute import SimpleImputer
from sklearn import tree
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

#filtering warnings
warnings.filterwarnings('ignore')

# %%
### reading CSV files into dataframes ###
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
full = pd.concat([train, test], axis=0, ignore_index=True)

# %%
### Calculating what percentage of loyals customers are satisfied with service and what percentage of disloyal customers are satisfied ###
loyals = []
disloyals = []
for i in range(len(full)):
    currRow = full.iloc[i]
    if (currRow['Customer Type'] == 'Loyal Customer'):
        loyals.append(currRow['satisfaction'])
    else:
        disloyals.append(currRow['satisfaction'])

        
loyalsSatisfied = 0
for i in range(len(loyals)):
    if (loyals[i] == 'satisfied'):
        loyalsSatisfied += 1

        
disloyalsSatisfied = 0
for i in range(len(disloyals)):
    if (disloyals[i] == 'satisfied'):
        disloyalsSatisfied += 1

# %%
### printing out the percentages calculated in cell above ###
print('There were ' + str(format((loyalsSatisfied / len(loyals)) * 100, '.2f')) + '% of loyal customers who were satisfied with the airline service.')
print('There were ' + str(format((disloyalsSatisfied / len(disloyals)) * 100, '.2f')) + '% of disloyal customers who were satisfied with the airline service.')
# Out:
# There were 47.81% of loyal customers who were satisfied with the airline service.
# There were 23.97% of disloyal customers who were satisfied with the airline service.

# %%
### function for avg and stdev ratings of all services for satisfied, dissatisfied and all customers ###
def avgRating(services):
    total = [[] for x in range(len(services))]
    satisfied = [[] for x in range(len(services))]
    dissatisfied = [[] for x in range(len(services))]

    for i in range(len(full)):
        currRow = full.iloc[i]
        
        if (currRow['satisfaction'] == 'satisfied'):
            for j in range(len(services)):
                if (currRow[services[j]] == 0):
                    continue
                    
                satisfied[j].append(currRow[services[j]])
        else:
            for j in range(len(services)):
                if (currRow[services[j]] == 0):
                    continue
                    
                dissatisfied[j].append(currRow[services[j]])
        
        for j in range(len(services)):
            if (currRow[services[j]] == 0):
                    continue
                    
            total[j].append(currRow[services[j]])
        
    ret = []
    for j in range(len(services)):
        ret.append([np.mean(satisfied[j]), np.std(satisfied[j]), np.mean(dissatisfied[j]), np.std(dissatisfied[j]), np.mean(total[j]), np.std(total[j])])

    return ret

# %%
### calling function above for each service offered to customer ###
services = ['Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness']
avgRatings = avgRating(services)

for i in range(len(avgRatings)):
    avgRatings[i].insert(0, services[i])
    
for i in range(len(avgRatings)):
    for j in range(1, len(avgRatings[i])):
        avgRatings[i][j] = format(avgRatings[i][j], '.2f')

# %%
### displaying calculated results in a dataframe ###
ratingsDF = pd.DataFrame(data = avgRatings)
ratingsDF.columns = ['Service', 'Average Satisfied Rating', 'Stdev of Satisfied Ratings', 'Average Dissatisfied Rating', 'Stdev of Dissatisfied Ratings', 'Average Total Rating', 'Stdev of Total Ratings']
ratingsDF
# Out:
#                               Service Average Satisfied Rating  \
# 0               Inflight wifi service                     3.39
# 1   Departure/Arrival time convenient                     3.14
# 2              Ease of Online booking                     3.24
# 3                       Gate location                     2.97
# 4                      Food and drink                     3.53
# 5                     Online boarding                     4.15
# 6                        Seat comfort                     3.97
# 7              Inflight entertainment                     3.96
# 8                    On-board service                     3.86
# 9                    Leg room service                     3.83
# 10                   Baggage handling                     3.97
# 11                    Checkin service                     3.65
# 12                   Inflight service                     3.97
# 13                        Cleanliness                     3.75
#
#    Stdev of Satisfied Ratings Average Dissatisfied Rating  \
# 0                        1.39                        2.40
# 1                        1.41                        3.29
# 2                        1.40                        2.62
# 3                        1.37                        2.98
# 4                        1.23                        2.96
# 5                        0.97                        2.71
# 6                        1.14                        3.04
# 7                        1.08                        2.89
# 8                        1.13                        3.02
# 9                        1.16                        3.01
# 10                       1.10                        3.37
# 11                       1.16                        3.04
# 12                       1.09                        3.39
# 13                       1.14                        2.93
#
#    Stdev of Dissatisfied Ratings Average Total Rating Stdev of Total Ratings
# 0                           0.96                 2.81                   1.26
# 1                           1.36                 3.22                   1.39
# 2                           1.15                 2.88                   1.30
# 3                           1.20                 2.98                   1.28
# 4                           1.34                 3.21                   1.33
# 5                           1.10                 3.33                   1.27
# 6                           1.30                 3.44                   1.32
# 7                           1.32                 3.36                   1.33
# 8                           1.28                 3.38                   1.29
# 9                           1.29                 3.37                   1.30
# 10                          1.18                 3.63                   1.18
# 11                          1.28                 3.31                   1.27
# 12                          1.18                 3.64                   1.18
# 13                          1.33                 3.29                   1.31

# %%
### preparing X train, y train, X test, and y test lists ###
X_train = []
y_train = []
X_test = []
y_test = []

X_train = train[train.columns.difference(['Unnamed: 0', 'id', 'satisfaction'])]
X_test = test[test.columns.difference(['Unnamed: 0', 'id', 'satisfaction'])]

y_train = train[['satisfaction']]
y_test = test[['satisfaction']]

# %%
### encoding values within the training and testing data to ordinal values ###
X_encoder = ce.OrdinalEncoder(cols=['Gender', 'Customer Type', 'Type of Travel', 'Class'])

X_train = X_encoder.fit_transform(X_train)
X_test = X_encoder.transform(X_test)

y_encoder = ce.OrdinalEncoder(cols=['satisfaction'])

y_train = y_encoder.fit_transform(y_train)
y_test = y_encoder.transform(y_test)

# %%
### imputing NaN's in the data ###
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
X_train[['Arrival Delay in Minutes']] = imputer.fit_transform(X_train[['Arrival Delay in Minutes']])
X_test[['Arrival Delay in Minutes']] = imputer.transform(X_test[['Arrival Delay in Minutes']])

# %%
### building and evaluating a MLP classifier on the dataset via 5-fold cross validation and a confusion matrix ###
mlp_clf = MLPClassifier(hidden_layer_sizes=(10, 10, 10), max_iter=500).fit(X_train, y_train)

scores = cross_val_score(mlp_clf, X_train, y_train, cv=5)
print(scores)

y_pred = mlp_clf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [0.92281411 0.93229392 0.92425774 0.91930128 0.93979788]
# [[13693   880]
#  [  977 10426]]
# 0.9285109331690792

# %%
### building a decision tree classifier and evaluating it ###
tree_clf = tree.DecisionTreeClassifier().fit(X_train, y_train)

scores = cross_val_score(tree_clf, X_train, y_train, cv=5)
print(scores)

y_pred = tree_clf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [0.94004138 0.94408354 0.94600837 0.94389105 0.94475457]
# [[13848   725]
#  [  664 10739]]
# 0.9465275639051433

# %%
### Applying GridSearch to find the best MLP Classifier ###
parameters = {'solver': ['adam', 'lbfgs', 'sgd'], 
              'max_iter': [1000, 1200, 1500, 2000], 
              'hidden_layer_sizes': [(10,10,10), (10, 5), (5,5), (100, 10, 50)],
              'alpha': [.0001, .005], 
              'learning_rate': ['constant', 'adaptive']}

mlp_clf = MLPClassifier()
gridClf = GridSearchCV(mlp_clf, parameters, cv=3)
gridClf.fit(X_train, y_train)
print("Grid search completed.")

print("\nHere are the best parameters:",gridClf.best_params_,"\n")

means = gridClf.cv_results_['mean_test_score']
stds = gridClf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, gridClf.cv_results_['params']):
    print("Mean: %0.3f, Std Dev: (+/-%0.03f), Parameters: %r"% (mean, std * 2, params))
    print()
    
#copy this in the morning...
# Out:
# Grid search completed.
#
# Here are the best parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.922, Std Dev: (+/-0.007), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.842, Std Dev: (+/-0.018), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.924, Std Dev: (+/-0.013), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.845, Std Dev: (+/-0.008), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.915, Std Dev: (+/-0.052), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.820, Std Dev: (+/-0.034), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.612, Std Dev: (+/-0.130), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.908, Std Dev: (+/-0.028), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.837, Std Dev: (+/-0.027), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.928, Std Dev: (+/-0.009), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.834, Std Dev: (+/-0.005), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.657, Std Dev: (+/-0.256), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.923, Std Dev: (+/-0.014), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.842, Std Dev: (+/-0.014), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.918, Std Dev: (+/-0.004), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.774, Std Dev: (+/-0.158), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.598, Std Dev: (+/-0.089), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.897, Std Dev: (+/-0.078), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.822, Std Dev: (+/-0.052), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.890, Std Dev: (+/-0.016), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.728, Std Dev: (+/-0.229), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.906, Std Dev: (+/-0.050), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.746, Std Dev: (+/-0.254), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.897, Std Dev: (+/-0.057), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.722, Std Dev: (+/-0.183), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.802, Std Dev: (+/-0.333), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.791, Std Dev: (+/-0.183), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.775, Std Dev: (+/-0.301), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.784, Std Dev: (+/-0.179), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.784, Std Dev: (+/-0.308), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.746, Std Dev: (+/-0.253), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.805, Std Dev: (+/-0.338), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.851, Std Dev: (+/-0.027), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.880, Std Dev: (+/-0.066), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.832, Std Dev: (+/-0.061), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.645, Std Dev: (+/-0.221), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.800, Std Dev: (+/-0.330), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.670, Std Dev: (+/-0.221), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.894, Std Dev: (+/-0.064), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.592, Std Dev: (+/-0.072), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.863, Std Dev: (+/-0.044), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.692, Std Dev: (+/-0.236), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.781, Std Dev: (+/-0.304), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.662, Std Dev: (+/-0.269), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.884, Std Dev: (+/-0.035), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.749, Std Dev: (+/-0.259), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.806, Std Dev: (+/-0.338), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.678, Std Dev: (+/-0.241), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.885, Std Dev: (+/-0.035), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.597, Std Dev: (+/-0.087), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.657, Std Dev: (+/-0.256), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.797, Std Dev: (+/-0.209), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.708, Std Dev: (+/-0.232), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.653, Std Dev: (+/-0.244), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.920, Std Dev: (+/-0.011), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.843, Std Dev: (+/-0.017), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.923, Std Dev: (+/-0.029), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.845, Std Dev: (+/-0.007), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.935, Std Dev: (+/-0.006), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.851, Std Dev: (+/-0.019), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.922, Std Dev: (+/-0.014), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.857, Std Dev: (+/-0.020), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.931, Std Dev: (+/-0.005), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.841, Std Dev: (+/-0.008), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.930, Std Dev: (+/-0.007), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.780, Std Dev: (+/-0.167), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.932, Std Dev: (+/-0.001), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.840, Std Dev: (+/-0.020), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.931, Std Dev: (+/-0.009), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.795, Std Dev: (+/-0.188), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.0001, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.910, Std Dev: (+/-0.020), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.644, Std Dev: (+/-0.328), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.927, Std Dev: (+/-0.003), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.840, Std Dev: (+/-0.019), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.566, Std Dev: (+/-0.001), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.923, Std Dev: (+/-0.011), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.844, Std Dev: (+/-0.038), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.566, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.927, Std Dev: (+/-0.004), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.833, Std Dev: (+/-0.035), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.922, Std Dev: (+/-0.013), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.795, Std Dev: (+/-0.138), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.658, Std Dev: (+/-0.257), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.929, Std Dev: (+/-0.003), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.839, Std Dev: (+/-0.009), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.657, Std Dev: (+/-0.257), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.926, Std Dev: (+/-0.009), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.760, Std Dev: (+/-0.273), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.656, Std Dev: (+/-0.253), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.917, Std Dev: (+/-0.014), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.792, Std Dev: (+/-0.182), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.651, Std Dev: (+/-0.238), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.894, Std Dev: (+/-0.083), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.765, Std Dev: (+/-0.145), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.001), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.792, Std Dev: (+/-0.319), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.847, Std Dev: (+/-0.026), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.789, Std Dev: (+/-0.318), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.688, Std Dev: (+/-0.226), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.917, Std Dev: (+/-0.017), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.760, Std Dev: (+/-0.274), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.914, Std Dev: (+/-0.016), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.744, Std Dev: (+/-0.251), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.687, Std Dev: (+/-0.342), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.843, Std Dev: (+/-0.040), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.920, Std Dev: (+/-0.014), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.763, Std Dev: (+/-0.278), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.643, Std Dev: (+/-0.215), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.778, Std Dev: (+/-0.300), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.758, Std Dev: (+/-0.272), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.897, Std Dev: (+/-0.048), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.765, Std Dev: (+/-0.154), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.807, Std Dev: (+/-0.340), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.657, Std Dev: (+/-0.255), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.894, Std Dev: (+/-0.053), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.758, Std Dev: (+/-0.213), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.783, Std Dev: (+/-0.307), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.691, Std Dev: (+/-0.234), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.897, Std Dev: (+/-0.039), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.747, Std Dev: (+/-0.256), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.880, Std Dev: (+/-0.029), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.598, Std Dev: (+/-0.089), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.923, Std Dev: (+/-0.017), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.752, Std Dev: (+/-0.262), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.916, Std Dev: (+/-0.022), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.691, Std Dev: (+/-0.222), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (5, 5), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.914, Std Dev: (+/-0.031), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.840, Std Dev: (+/-0.008), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.922, Std Dev: (+/-0.025), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.842, Std Dev: (+/-0.004), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.932, Std Dev: (+/-0.005), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.849, Std Dev: (+/-0.005), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.924, Std Dev: (+/-0.006), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.865, Std Dev: (+/-0.004), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'sgd'}
#
# Mean: 0.923, Std Dev: (+/-0.010), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
#
# Mean: 0.837, Std Dev: (+/-0.017), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'sgd'}
#
# Mean: 0.931, Std Dev: (+/-0.004), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'adam'}
#
# Mean: 0.838, Std Dev: (+/-0.006), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1200, 'solver': 'sgd'}
#
# Mean: 0.923, Std Dev: (+/-0.003), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'adam'}
#
# Mean: 0.794, Std Dev: (+/-0.190), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 1500, 'solver': 'sgd'}
#
# Mean: 0.930, Std Dev: (+/-0.005), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
#
# Mean: 0.854, Std Dev: (+/-0.020), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'lbfgs'}
#
# Mean: 0.567, Std Dev: (+/-0.000), Parameters: {'alpha': 0.005, 'hidden_layer_sizes': (100, 10, 50), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'sgd'}

# %%
### Applying GridSearch to find the best DecisionTree Classifier ###
#default params: criterion : gini, splitter : best, max_depth : None,
#   min_samples_split : 2, min_samples_leaf : 1, max_features : None
parameters = {'criterion' : ['gini', 'entropy'],
              'splitter' : ['best', 'random'],
              'min_samples_split' : [1, 2, 4, 8],
              'min_samples_leaf' : [1, 2, 4, 8],
              'max_features' : [None, 'auto', 'sqrt', 'log2'],
              'max_depth' : [2, 4, 8, 16, 32, None]}

tree_clf = tree.DecisionTreeClassifier()
gridClf = GridSearchCV(tree_clf, parameters, cv=3)
gridClf.fit(X_train, y_train)
print("Grid search completed.")

print("\nHere are the best parameters:",gridClf.best_params_,"\n")

means = gridClf.cv_results_['mean_test_score']
stds = gridClf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, gridClf.cv_results_['params']):
    print("Mean: %0.3f, Std Dev: (+/-%0.03f), Parameters: %r"% (mean, std * 2, params))
    print()
# Out:
# Grid search completed.
#
# Here are the best parameters: {'criterion': 'entropy', 'max_depth': 16, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.787, Std Dev: (+/-0.031), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.756, Std Dev: (+/-0.043), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.795, Std Dev: (+/-0.027), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.789, Std Dev: (+/-0.019), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.780, Std Dev: (+/-0.029), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.782, Std Dev: (+/-0.072), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.812, Std Dev: (+/-0.125), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.746, Std Dev: (+/-0.043), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.759, Std Dev: (+/-0.048), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.825, Std Dev: (+/-0.060), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.779, Std Dev: (+/-0.105), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.825, Std Dev: (+/-0.051), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.785, Std Dev: (+/-0.037), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.685, Std Dev: (+/-0.152), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.783, Std Dev: (+/-0.021), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.697, Std Dev: (+/-0.112), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.708, Std Dev: (+/-0.095), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.710, Std Dev: (+/-0.028), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.799, Std Dev: (+/-0.066), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.680, Std Dev: (+/-0.175), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.783, Std Dev: (+/-0.045), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.678, Std Dev: (+/-0.055), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.795, Std Dev: (+/-0.024), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.656, Std Dev: (+/-0.038), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.795, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.637, Std Dev: (+/-0.057), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.748, Std Dev: (+/-0.046), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.736, Std Dev: (+/-0.032), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.750, Std Dev: (+/-0.138), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.670, Std Dev: (+/-0.070), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.780, Std Dev: (+/-0.070), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.711, Std Dev: (+/-0.145), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.790, Std Dev: (+/-0.018), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.719, Std Dev: (+/-0.071), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.757, Std Dev: (+/-0.068), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.716, Std Dev: (+/-0.075), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.754, Std Dev: (+/-0.087), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.711, Std Dev: (+/-0.115), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.772, Std Dev: (+/-0.089), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.670, Std Dev: (+/-0.033), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.807, Std Dev: (+/-0.062), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.686, Std Dev: (+/-0.157), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.814, Std Dev: (+/-0.047), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.709, Std Dev: (+/-0.091), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.793, Std Dev: (+/-0.044), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.655, Std Dev: (+/-0.134), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.826, Std Dev: (+/-0.036), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.713, Std Dev: (+/-0.123), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.753, Std Dev: (+/-0.056), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.736, Std Dev: (+/-0.164), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.785, Std Dev: (+/-0.037), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.697, Std Dev: (+/-0.031), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.775, Std Dev: (+/-0.015), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.722, Std Dev: (+/-0.130), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.747, Std Dev: (+/-0.101), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.705, Std Dev: (+/-0.124), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.784, Std Dev: (+/-0.123), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.749, Std Dev: (+/-0.060), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.772, Std Dev: (+/-0.023), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.680, Std Dev: (+/-0.060), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.783, Std Dev: (+/-0.009), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.779, Std Dev: (+/-0.011), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.780, Std Dev: (+/-0.033), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.670, Std Dev: (+/-0.157), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.764, Std Dev: (+/-0.045), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.676, Std Dev: (+/-0.015), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.785, Std Dev: (+/-0.025), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.671, Std Dev: (+/-0.052), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.800, Std Dev: (+/-0.039), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.714, Std Dev: (+/-0.138), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.730, Std Dev: (+/-0.026), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.704, Std Dev: (+/-0.027), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.787, Std Dev: (+/-0.042), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.793, Std Dev: (+/-0.087), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.770, Std Dev: (+/-0.038), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.695, Std Dev: (+/-0.105), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.733, Std Dev: (+/-0.047), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.706, Std Dev: (+/-0.026), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.767, Std Dev: (+/-0.015), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.657, Std Dev: (+/-0.016), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.774, Std Dev: (+/-0.072), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.730, Std Dev: (+/-0.161), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.788, Std Dev: (+/-0.126), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.676, Std Dev: (+/-0.062), Parameters: {'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.887, Std Dev: (+/-0.033), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.878, Std Dev: (+/-0.028), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.876, Std Dev: (+/-0.020), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.885, Std Dev: (+/-0.012), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.875, Std Dev: (+/-0.044), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.867, Std Dev: (+/-0.036), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.877, Std Dev: (+/-0.020), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.874, Std Dev: (+/-0.026), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.880, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.858, Std Dev: (+/-0.052), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.870, Std Dev: (+/-0.014), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.890, Std Dev: (+/-0.004), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.874, Std Dev: (+/-0.028), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.836, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.788, Std Dev: (+/-0.055), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.845, Std Dev: (+/-0.026), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.799, Std Dev: (+/-0.036), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.830, Std Dev: (+/-0.020), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.821, Std Dev: (+/-0.053), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.836, Std Dev: (+/-0.066), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.786, Std Dev: (+/-0.078), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.842, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.793, Std Dev: (+/-0.106), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.863, Std Dev: (+/-0.014), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.810, Std Dev: (+/-0.058), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.852, Std Dev: (+/-0.031), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.755, Std Dev: (+/-0.105), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.829, Std Dev: (+/-0.031), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.802, Std Dev: (+/-0.069), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.862, Std Dev: (+/-0.030), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.796, Std Dev: (+/-0.040), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.842, Std Dev: (+/-0.023), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.779, Std Dev: (+/-0.076), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.834, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.770, Std Dev: (+/-0.042), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.863, Std Dev: (+/-0.039), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.778, Std Dev: (+/-0.038), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.837, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.806, Std Dev: (+/-0.035), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.838, Std Dev: (+/-0.080), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.814, Std Dev: (+/-0.059), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.844, Std Dev: (+/-0.062), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.759, Std Dev: (+/-0.071), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.830, Std Dev: (+/-0.021), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.779, Std Dev: (+/-0.064), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.840, Std Dev: (+/-0.063), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.796, Std Dev: (+/-0.080), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.827, Std Dev: (+/-0.085), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.764, Std Dev: (+/-0.097), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.839, Std Dev: (+/-0.017), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.814, Std Dev: (+/-0.053), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.859, Std Dev: (+/-0.046), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.785, Std Dev: (+/-0.015), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.854, Std Dev: (+/-0.018), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.767, Std Dev: (+/-0.091), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.838, Std Dev: (+/-0.031), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.799, Std Dev: (+/-0.016), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.825, Std Dev: (+/-0.026), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.795, Std Dev: (+/-0.062), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.833, Std Dev: (+/-0.013), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.809, Std Dev: (+/-0.030), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.842, Std Dev: (+/-0.051), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.823, Std Dev: (+/-0.019), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.824, Std Dev: (+/-0.065), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.786, Std Dev: (+/-0.053), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.854, Std Dev: (+/-0.036), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.792, Std Dev: (+/-0.173), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.848, Std Dev: (+/-0.012), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.785, Std Dev: (+/-0.050), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.837, Std Dev: (+/-0.044), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.801, Std Dev: (+/-0.041), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.847, Std Dev: (+/-0.006), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.804, Std Dev: (+/-0.023), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.823, Std Dev: (+/-0.057), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.795, Std Dev: (+/-0.087), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.848, Std Dev: (+/-0.021), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.837, Std Dev: (+/-0.016), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.840, Std Dev: (+/-0.018), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.815, Std Dev: (+/-0.011), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.843, Std Dev: (+/-0.029), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.728, Std Dev: (+/-0.126), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.835, Std Dev: (+/-0.045), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.806, Std Dev: (+/-0.036), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.822, Std Dev: (+/-0.020), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.767, Std Dev: (+/-0.064), Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.932, Std Dev: (+/-0.008), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.929, Std Dev: (+/-0.010), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.927, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.003), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.929, Std Dev: (+/-0.005), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.930, Std Dev: (+/-0.002), Parameters: {'criterion': 'gini', 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# ...
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.937, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.009), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.929, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.013), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.928, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.915, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.931, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.922, Std Dev: (+/-0.015), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.014), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.930, Std Dev: (+/-0.006), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.012), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.931, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.000), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.928, Std Dev: (+/-0.013), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.927, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.916, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.013), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.002), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.921, Std Dev: (+/-0.009), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.937, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.010), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.924, Std Dev: (+/-0.006), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.936, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.916, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.918, Std Dev: (+/-0.012), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.916, Std Dev: (+/-0.003), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.927, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.918, Std Dev: (+/-0.006), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.934, Std Dev: (+/-0.006), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.927, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.929, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.929, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.923, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.931, Std Dev: (+/-0.009), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.919, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.012), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.928, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.931, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.918, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.935, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.926, Std Dev: (+/-0.004), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.007), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.925, Std Dev: (+/-0.015), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 8, 'splitter': 'random'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'best'}
#
# Mean: nan, Std Dev: (+/-nan), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 1, 'splitter': 'random'}
#
# Mean: 0.931, Std Dev: (+/-0.013), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'best'}
#
# Mean: 0.915, Std Dev: (+/-0.008), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'splitter': 'random'}
#
# Mean: 0.933, Std Dev: (+/-0.011), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'best'}
#
# Mean: 0.920, Std Dev: (+/-0.009), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 4, 'splitter': 'random'}
#
# Mean: 0.932, Std Dev: (+/-0.005), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'best'}
#
# Mean: 0.927, Std Dev: (+/-0.016), Parameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 8, 'splitter': 'random'}
